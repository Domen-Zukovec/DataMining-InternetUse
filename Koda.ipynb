# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
f = open("C:/Users/zukov/Desktop/PR Seminarska/RudarjenjePodatki2.csv")
df = pd.read_csv(f)

# %%
df
# Out:
#      LETO                            NAMEN UPORABE INTERNETA  \
# 0    2015                               Posamezniki - SKUPAJ
# 1    2015  Uporaba interneta v zadnjih 3 mesecih (redni u...
# 2    2015                 .Pošiljanje ali prejemanje e-pošte
# 3    2015                                      .E-banèništvo
# 4    2015             .Iskanje informacij o blagu, storitvah
# ..    ...                                                ...
# 355  2020               .Izdelava spletnih strani ali blogov
# 356  2020  .Uporaba storitev, povezanih s potovanji in na...
# 357  2020      .Iskanje službe, pošiljanje prošenj za službo
# 358  2020                      .Prenašanje programske opreme
# 359  2020  .Uporaba ali odprtje predplaèniškega raèuna, n...
#
#      Število posameznikov - SKUPAJ   16-24   25-34   35-44   45-54   55-64  \
# 0                          1554075  183692  280417  302780  304599  290628
# 1                          1136008  182580  272064  281005  215522  133206
# ...

# %%
tmp = df.loc[(df["Moški - SKUPAJ"]!=0) & (df["LETO"]==2015)]
m15 = tmp[["NAMEN UPORABE INTERNETA", "Moški - SKUPAJ" ]]
m15 = m15.sort_values(by=["Moški - SKUPAJ"], ascending=False)
tmp = m15[1:11]

tmp2 = df.loc[(df["Ženske - SKUPAJ"]!=0) & (df["LETO"]==2015)]
z15 = tmp2[["NAMEN UPORABE INTERNETA", "Ženske - SKUPAJ" ]]
z15 = z15.sort_values(by=["Ženske - SKUPAJ"], ascending=False)
tmp2 = z15[1:11]

fig, axs = plt.subplots(1,2)

tmp.plot(x="NAMEN UPORABE INTERNETA", y="Moški - SKUPAJ", kind="bar", fontsize=12, figsize=(14,5),ax=axs[0])
tmp2.plot(x="NAMEN UPORABE INTERNETA", y="Ženske - SKUPAJ", kind="bar", fontsize=12, figsize=(14,5),ax=axs[1])
# Out:
# <AxesSubplot:xlabel='NAMEN UPORABE INTERNETA'>

# %%
tmp = df.loc[(df["Moški 16-24"]!=0) & (df["LETO"]==2015)]
m15 = tmp[["NAMEN UPORABE INTERNETA", "Moški 16-24" ]]
m15 = m15.sort_values(by=["Moški 16-24"], ascending=False)
tmp = m15[1:11]

tmp2 = df.loc[(df["Ženske 16-24"]!=0) & (df["LETO"]==2015)]
z15 = tmp2[["NAMEN UPORABE INTERNETA", "Ženske 16-24" ]]
z15 = z15.sort_values(by=["Ženske 16-24"], ascending=False)
tmp2 = z15[1:11]

fig, axs = plt.subplots(1,2)

tmp.plot(x="NAMEN UPORABE INTERNETA", y="Moški 16-24", kind="bar", fontsize=12, figsize=(14,5),ax=axs[0])
tmp2.plot(x="NAMEN UPORABE INTERNETA", y="Ženske 16-24", kind="bar", fontsize=12, figsize=(14,5),ax=axs[1])
# Out:
# <AxesSubplot:xlabel='NAMEN UPORABE INTERNETA'>

# %%
tmp = df.loc[(df["Moški 25-54"]!=0) & (df["LETO"]==2015)]
m15 = tmp[["NAMEN UPORABE INTERNETA", "Moški 25-54" ]]
m15 = m15.sort_values(by=["Moški 25-54"], ascending=False)
tmp = m15[1:11]

tmp2 = df.loc[(df["Ženske 25-54"]!=0) & (df["LETO"]==2015)]
z15 = tmp2[["NAMEN UPORABE INTERNETA", "Ženske 25-54" ]]
z15 = z15.sort_values(by=["Ženske 25-54"], ascending=False)
tmp2 = z15[1:11]

fig, axs = plt.subplots(1,2)

tmp.plot(x="NAMEN UPORABE INTERNETA", y="Moški 25-54", kind="bar", fontsize=12, figsize=(14,5),ax=axs[0])
tmp2.plot(x="NAMEN UPORABE INTERNETA", y="Ženske 25-54", kind="bar", fontsize=12, figsize=(14,5),ax=axs[1])
# Out:
# <AxesSubplot:xlabel='NAMEN UPORABE INTERNETA'>

# %%
tmp = df.loc[(df["Moški 55-74"]!=0) & (df["LETO"]==2015)]
m15 = tmp[["NAMEN UPORABE INTERNETA", "Moški 55-74" ]]
m15 = m15.sort_values(by=["Moški 55-74"], ascending=False)
tmp = m15[1:11]

tmp2 = df.loc[(df["Ženske 55-74"]!=0) & (df["LETO"]==2015)]
z15 = tmp2[["NAMEN UPORABE INTERNETA", "Ženske 55-74" ]]
z15 = z15.sort_values(by=["Ženske 55-74"], ascending=False)
tmp2 = z15[1:11]

fig, axs = plt.subplots(1,2)

tmp.plot(x="NAMEN UPORABE INTERNETA", y="Moški 55-74", kind="bar", fontsize=12, figsize=(14,5),ax=axs[0])
tmp2.plot(x="NAMEN UPORABE INTERNETA", y="Ženske 55-74", kind="bar", fontsize=12, figsize=(14,5),ax=axs[1])
# Out:
# <AxesSubplot:xlabel='NAMEN UPORABE INTERNETA'>

# %%
tmp = df.loc[(df["Moški 16-24"]!=0) & (df["LETO"]==2015)]
m15 = tmp[["NAMEN UPORABE INTERNETA", "Moški 16-24" ]]
m15 = m15.sort_values(by=["Moški 16-24"], ascending=False)
tmp = m15[1:11]

tmp2 = df.loc[(df["Moški 25-54"]!=0) & (df["LETO"]==2015)]
m115 = tmp2[["NAMEN UPORABE INTERNETA", "Moški 25-54" ]]
m115 = m115.sort_values(by=["Moški 25-54"], ascending=False)
tmp2 = m115[1:11]

tmp3 = df.loc[(df["Moški 55-74"]!=0) & (df["LETO"]==2015)]
m215 = tmp3[["NAMEN UPORABE INTERNETA", "Moški 55-74" ]]
m215 = m215.sort_values(by=["Moški 55-74"], ascending=False)
tmp3 = m215[1:11]


fig, axs = plt.subplots(1,3)

tmp.plot(x="NAMEN UPORABE INTERNETA", y="Moški 16-24", kind="bar", fontsize=12, figsize=(16,5),ax=axs[0])
tmp2.plot(x="NAMEN UPORABE INTERNETA", y="Moški 25-54", kind="bar", fontsize=12, figsize=(16,5),ax=axs[1])
tmp3.plot(x="NAMEN UPORABE INTERNETA", y="Moški 55-74", kind="bar", fontsize=12, figsize=(16,5),ax=axs[2])
# Out:
# <AxesSubplot:xlabel='NAMEN UPORABE INTERNETA'>

# %%
tmp = df.loc[(df["Ženske 16-24"]!=0) & (df["LETO"]==2015)]
m15 = tmp[["NAMEN UPORABE INTERNETA", "Ženske 16-24" ]]
m15 = m15.sort_values(by=["Ženske 16-24"], ascending=False)
tmp = m15[1:11]

tmp2 = df.loc[(df["Ženske 25-54"]!=0) & (df["LETO"]==2015)]
m115 = tmp2[["NAMEN UPORABE INTERNETA", "Ženske 25-54" ]]
m115 = m115.sort_values(by=["Ženske 25-54"], ascending=False)
tmp2 = m115[1:11]

tmp3 = df.loc[(df["Ženske 55-74"]!=0) & (df["LETO"]==2015)]
m215 = tmp3[["NAMEN UPORABE INTERNETA", "Ženske 55-74" ]]
m215 = m215.sort_values(by=["Ženske 55-74"], ascending=False)
tmp3 = m215[1:11]


fig, axs = plt.subplots(1,3)

tmp.plot(x="NAMEN UPORABE INTERNETA", y="Ženske 16-24", kind="bar", fontsize=12, figsize=(16,5),ax=axs[0])
tmp2.plot(x="NAMEN UPORABE INTERNETA", y="Ženske 25-54", kind="bar", fontsize=12, figsize=(16,5),ax=axs[1])
tmp3.plot(x="NAMEN UPORABE INTERNETA", y="Ženske 55-74", kind="bar", fontsize=12, figsize=(16,5),ax=axs[2])
# Out:
# <AxesSubplot:xlabel='NAMEN UPORABE INTERNETA'>

# %%
skupaj = df.loc[(df["NAMEN UPORABE INTERNETA"]=="Posamezniki - SKUPAJ")]

m = skupaj[["Moški - SKUPAJ" ]]
z = skupaj[["Ženske - SKUPAJ" ]]
leta = [2015, 2016, 2017, 2018, 2019, 2020]
m['leto'] = leta
z['leto'] = leta
print(m,'\n\n', z)

fig, axs = plt.subplots(1,2)

m.plot(x="leto", y="Moški - SKUPAJ", ax=axs[0], figsize=(16,5))
z.plot(x="leto", y="Ženske - SKUPAJ", ax=axs[1],figsize=(16,5))
# Out:
#      Moški - SKUPAJ  leto
# 0            787481  2015
# 60           789234  2016
# 120          779328  2017
# 180          781532  2018
# 240          789361  2019
# 300          798631  2020
#
#       Ženske - SKUPAJ  leto
# 0             766594  2015
# 60            758496  2016
# 120           754873  2017
# 180           756644  2018
# 240           755770  2019
# 300           756214  2020
# <ipython-input-10-6db066b11a7d>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m['leto'] = leta
# <ipython-input-10-6db066b11a7d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
skupaj = df.loc[(df["NAMEN UPORABE INTERNETA"]=="Posamezniki - SKUPAJ")]

m1 = skupaj[["Moški 16-24" ]]
m2 = skupaj[["Moški 25-54" ]]
m3 = skupaj[["Moški 55-74" ]]
leta = [2015, 2016, 2017, 2018, 2019, 2020]
m1['leto'] = leta
m2['leto'] = leta
m3['leto'] = leta

fig, axs = plt.subplots(1,3)

m1.plot(x="leto", y="Moški 16-24", ax=axs[0], figsize=(16,5))
m2.plot(x="leto", y="Moški 25-54", ax=axs[1],figsize=(16,5))
m3.plot(x="leto", y="Moški 55-74", ax=axs[2],figsize=(16,5))
# Out:
# <ipython-input-11-607238921c78>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m1['leto'] = leta
# <ipython-input-11-607238921c78>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m2['leto'] = leta
# <ipython-input-11-607238921c78>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
skupaj = df.loc[(df["NAMEN UPORABE INTERNETA"]=="Posamezniki - SKUPAJ")]

m1 = skupaj[["Moški 16-24"]]
m2 = skupaj[["Moški 25-54"]]
m3 = skupaj[["Moški 55-74"]]
ms = skupaj[["Moški - SKUPAJ"]]
tab = []
tab2 = []
tab3 = []
leta = [2015, 2016, 2017, 2018, 2019, 2020]

for i in range(0, 301, 60):
    tab.append(m1["Moški 16-24"][i] / ms["Moški - SKUPAJ"][i])
    
for i in range(0, 301, 60):
    tab2.append(m2["Moški 25-54"][i] / ms["Moški - SKUPAJ"][i])

for i in range(0, 301, 60):
    tab3.append(m3["Moški 55-74"][i] / ms["Moški - SKUPAJ"][i])

fig, axes = plt.subplots(1, 3, figsize=(16,5))


axes[0].plot(leta, tab)
axes[1].plot(leta, tab2)
axes[2].plot(leta, tab3)

# %%
skupaj = df.loc[(df["NAMEN UPORABE INTERNETA"]=="Posamezniki - SKUPAJ")]

m1 = skupaj[["Ženske 16-24" ]]
m2 = skupaj[["Ženske 25-54" ]]
m3 = skupaj[["Ženske 55-74" ]]
leta = [2015, 2016, 2017, 2018, 2019, 2020]
m1['leto'] = leta
m2['leto'] = leta
m3['leto'] = leta

fig, axs = plt.subplots(1,3)

m1.plot(x="leto", y="Ženske 16-24", ax=axs[0], figsize=(16,5))
m2.plot(x="leto", y="Ženske 25-54", ax=axs[1],figsize=(16,5))
m3.plot(x="leto", y="Ženske 55-74", ax=axs[2],figsize=(16,5))
# Out:
# <ipython-input-13-0d54bf1df977>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m1['leto'] = leta
# <ipython-input-13-0d54bf1df977>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m2['leto'] = leta
# <ipython-input-13-0d54bf1df977>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
skupaj = df.loc[(df["NAMEN UPORABE INTERNETA"]=="Posamezniki - SKUPAJ")]

m1 = skupaj[["Ženske 16-24"]]
m2 = skupaj[["Ženske 25-54"]]
m3 = skupaj[["Ženske 55-74"]]
ms = skupaj[["Ženske - SKUPAJ"]]
tab = []
tab2 = []
tab3 = []
leta = [2015, 2016, 2017, 2018, 2019, 2020]

for i in range(0, 301, 60):
    tab.append(m1["Ženske 16-24"][i] / ms["Ženske - SKUPAJ"][i])
    
for i in range(0, 301, 60):
    tab2.append(m2["Ženske 25-54"][i] / ms["Ženske - SKUPAJ"][i])

for i in range(0, 301, 60):
    tab3.append(m3["Ženske 55-74"][i] / ms["Ženske - SKUPAJ"][i])

fig, axes = plt.subplots(1, 3, figsize=(16,5))


axes[0].plot(leta, tab)
axes[1].plot(leta, tab2)
axes[2].plot(leta, tab3)

# %% [markdown]
# **Katere dejavnosti so bile skozi leta najbolj uporabljene?**

# %%
tmp = df.loc[(df["Število posameznikov - SKUPAJ"]!=0)]
top = {}
for i,j in zip(tmp["NAMEN UPORABE INTERNETA"], tmp["Število posameznikov - SKUPAJ"]):
    if i not in top.keys():
        top[i] = j;
    else:
        top[i] += j;

# %%
top = {k: v for k, v in sorted(top.items(), key=lambda item: item[1], reverse=True)}
x = top.keys()
x_l = list(x)
y = top.values()
y_l = list(y)

# %%
y
# Out:
# dict_values([9274158, 7372126, 6460409, 6350276, 4808962, 4706722, 4465086, 3845886, 3530808, 3033945, 2593945, 2439639, 2252832, 1774351, 1696039, 1691608, 1597360, 1363950, 1305025, 1251522, 1144438, 1032719, 1026764, 1016776, 937862, 761686, 737581, 669948, 611750, 583357, 488762, 480675, 408690, 405873, 393875, 348471, 301629, 301126, 259208, 252304, 249151, 239139, 227781, 226037, 203897, 202846, 196701, 160379, 136515, 132494, 109205, 96993, 86829, 63642, 57068, 38407, 28972, 8043, 8043, 7881])

# %%
plt.barh(x_l[2:8], y_l[2:8], color = "lightblue")
plt.xlabel("Uporaba v miljonih")
plt.ylabel("Namen")
plt.title("Najbolj uporabljene dejavnosti na internetu v zadnjih petih letih")
plt.show()
print(x_l[0], y_l[0])
# Out:
# Posamezniki - SKUPAJ 9274158

# %% [markdown]
# **Kako se popularnost določene dejavnosti skozi leta spreminja**

# %%
tmp = df.loc[(df["Število posameznikov - SKUPAJ"]!=0)]
nihanje = []
letno = []

for i,j in zip(tmp["NAMEN UPORABE INTERNETA"], tmp["Število posameznikov - SKUPAJ"]):
    if i == ".Pošiljanje ali prejemanje e-pošte":
        nihanje.append(j)
        
for i,j in zip(tmp["NAMEN UPORABE INTERNETA"], tmp["Število posameznikov - SKUPAJ"]):
    if i == "Posamezniki - SKUPAJ":
        letno.append(j)
        
nihanje_proc = []
for i, j in zip(nihanje, letno):
    nihanje_proc.append(i/j)
    
nihanje2 = []
letno2 = []

for i,j in zip(tmp["NAMEN UPORABE INTERNETA"], tmp["Število posameznikov - SKUPAJ"]):
    if i == ".Iskanje informacij o blagu, storitvah":
        nihanje2.append(j)
        
for i,j in zip(tmp["NAMEN UPORABE INTERNETA"], tmp["Število posameznikov - SKUPAJ"]):
    if i == "Posamezniki - SKUPAJ":
        letno2.append(j)
        
nihanje2_proc = []
for i, j in zip(nihanje2, letno2):
    nihanje2_proc.append(i/j)
    
    
    
nihanje3 = []
letno3 = []

for i,j in zip(tmp["NAMEN UPORABE INTERNETA"], tmp["Število posameznikov - SKUPAJ"]):
    if i == "..Iskanje informacij, povezanih z zdravjem":
        nihanje3.append(j)
        
for i,j in zip(tmp["NAMEN UPORABE INTERNETA"], tmp["Število posameznikov - SKUPAJ"]):
    if i == "Posamezniki - SKUPAJ":
        letno3.append(j)
        
nihanje3_proc = []
for i, j in zip(nihanje3, letno3):
    nihanje3_proc.append(i/j)

nihanje_st = [2015, 2016, 2017, 2018, 2019, 2020]




fig, axes = plt.subplots(1, 3, figsize=(16,5))

print("      e-mail                                  infomacije o blagu in storitvah          informacije o zdravju")
axes[0].plot(nihanje_st, nihanje_proc, 'g')
axes[1].plot(nihanje_st, nihanje2_proc, 'g')
axes[2].plot(nihanje_st, nihanje3_proc, 'r')
# Out:
#       e-mail                                  infomacije o blagu in storitvah          informacije o zdravju

# %% [markdown]
# **razlike med najbolj uporabljenimi nameni interneta skozi leta 2015-2020**

# %%
l15 = df.loc[(df["Število posameznikov - SKUPAJ"]!=0) & (df["LETO"]==2015)]
l16 = df.loc[(df["Število posameznikov - SKUPAJ"]!=0) & (df["LETO"]==2016)]
l17 = df.loc[(df["Število posameznikov - SKUPAJ"]!=0) & (df["LETO"]==2017)]
l18 = df.loc[(df["Število posameznikov - SKUPAJ"]!=0) & (df["LETO"]==2018)]
l19 = df.loc[(df["Število posameznikov - SKUPAJ"]!=0) & (df["LETO"]==2019)]
l20 = df.loc[(df["Število posameznikov - SKUPAJ"]!=0) & (df["LETO"]==2020)]

t15 = {}
for i,j in zip(l15["NAMEN UPORABE INTERNETA"], l15["Število posameznikov - SKUPAJ"]):
    if i not in t15.keys():
        t15[i] = j;
    else:
        t15[i] += j;
t15 = {k: v for k, v in sorted(t15.items(), key=lambda item: item[1], reverse=True)}

t16 = {}
for i,j in zip(l16["NAMEN UPORABE INTERNETA"], l16["Število posameznikov - SKUPAJ"]):
    if i not in t16.keys():
        t16[i] = j;
    else:
        t16[i] += j;
t16 = {k: v for k, v in sorted(t16.items(), key=lambda item: item[1], reverse=True)}

t17 = {}
for i,j in zip(l17["NAMEN UPORABE INTERNETA"], l17["Število posameznikov - SKUPAJ"]):
    if i not in t17.keys():
        t17[i] = j;
    else:
        t17[i] += j;
t17 = {k: v for k, v in sorted(t17.items(), key=lambda item: item[1], reverse=True)}


t18 = {}
for i,j in zip(l18["NAMEN UPORABE INTERNETA"], l18["Število posameznikov - SKUPAJ"]):
    if i not in t18.keys():
        t18[i] = j;
    else:
        t18[i] += j;
t18 = {k: v for k, v in sorted(t18.items(), key=lambda item: item[1], reverse=True)}

t19 = {}
for i,j in zip(l19["NAMEN UPORABE INTERNETA"], l19["Število posameznikov - SKUPAJ"]):
    if i not in t19.keys():
        t19[i] = j;
    else:
        t19[i] += j;
t19 = {k: v for k, v in sorted(t19.items(), key=lambda item: item[1], reverse=True)}

t20 = {}
for i,j in zip(l20["NAMEN UPORABE INTERNETA"], l20["Število posameznikov - SKUPAJ"]):
    if i not in t20.keys():
        t20[i] = j;
    else:
        t20[i] += j;
t20 = {k: v for k, v in sorted(t20.items(), key=lambda item: item[1], reverse=True)}

x1 = t15.keys()
x11 = list(x1)
y1 = t15.values()
y11 = list(y1)

x2 = t16.keys()
x22 = list(x2)
y2 = t16.values()
y22 = list(y2)


x3 = t17.keys()
x33 = list(x3)
y3 = t17.values()
y33 = list(y3)


x4 = t18.keys()
x44 = list(x4)
y4 = t18.values()
y44 = list(y4)

x5 = t19.keys()
x55 = list(x5)
y5 = t19.values()
y55 = list(y5)

x6 = t20.keys()
x66 = list(x6)
y6 = t20.values()
y66 = list(y6)

print("2015:")
for i,j in zip(x11[2:7],y11[2:7]):
    print(i.replace(".","") , " -- ", j)
    
print("\n2016:")
for i,j in zip(x22[2:7],y22[2:7]):
    print(i.replace(".","") , " -- ", j)

print("\n2017:")
for i,j in zip(x33[2:7],y33[2:7]):
    print(i.replace(".","") , " -- ", j)

print("\n2018:")    
for i,j in zip(x33[2:7],y33[2:7]):
    print(i.replace(".","") , " -- ", j)
    
print("\n2019:")
for i,j in zip(x33[2:7],y33[2:7]):
    print(i.replace(".","") , " -- ", j)
    
print("\n2020:")
for i,j in zip(x33[2:7],y33[2:7]):
    print(i.replace(".","") , " -- ", j)
# Out:
# 2015:
# Pošiljanje ali prejemanje e-pošte  --  984153
# Iskanje informacij o blagu, storitvah  --  947544
# Branje spletni novic, spletnih èasopisov, spletnih revij  --  870813
# Iskanje informacij, povezanih z zdravjem  --  735236
# Uporaba storitev, povezanih s potovanji in nastanitvijo  --  600773
#
# 2016:
# Pošiljanje ali prejemanje e-pošte  --  1020811
# Iskanje informacij o blagu, storitvah  --  1000490
# Branje spletni novic, spletnih èasopisov, spletnih revij  --  931211
# Iskanje informacij, povezanih z zdravjem  --  748732
# Gledanje video vsebin na spletnih straneh za deljenje video vsebin, npr YouTube  --  740577
#
# 2017:
# Iskanje informacij o blagu, storitvah  --  1064399
# Pošiljanje ali prejemanje e-pošte  --  1058666
# Branje spletni novic, spletnih èasopisov, spletnih revij  --  928648
# Iskanje informacij, povezanih z zdravjem  --  836098
# Sodelovanje v spletnih družabnih ali profesionalnih omrežjih  --  708830
#
# 2018:
# ...

# %% [markdown]
# **Pri katerem starostnem razredu je največja oz. najmanjša razlika med spoloma**

# %%
tmp = df.loc[(df["Število posameznikov - SKUPAJ"]!=0)]
m1 = {}
for i,j in zip(tmp["NAMEN UPORABE INTERNETA"], tmp["Moški 16-24"]):
    if i not in m1.keys():
        m1[i] = j;
    else:
        m1[i] += j;
        
m1 = {k: v for k, v in sorted(m1.items(), key=lambda item: item[1], reverse=True)}
xm1 = m1.keys()
xm11 = list(xm1)
ym1 = m1.values()
ym11 = list(ym1)

# %%
tmp = df.loc[(df["Število posameznikov - SKUPAJ"]!=0)]
m2 = {}
for i,j in zip(tmp["NAMEN UPORABE INTERNETA"], tmp["Moški 25-54"]):
    if i not in m2.keys():
        m2[i] = j;
    else:
        m2[i] += j;
        
m2 = {k: v for k, v in sorted(m2.items(), key=lambda item: item[1], reverse=True)}
xm2 = m2.keys()
xm22 = list(xm2)
ym2 = m2.values()
ym22 = list(ym2)

# %%
tmp = df.loc[(df["Število posameznikov - SKUPAJ"]!=0)]
m3 = {}
for i,j in zip(tmp["NAMEN UPORABE INTERNETA"], tmp["Moški 55-74"]):
    if i not in m3.keys():
        m3[i] = j;
    else:
        m3[i] += j;
        
m3 = {k: v for k, v in sorted(m3.items(), key=lambda item: item[1], reverse=True)}
xm3 = m3.keys()
xm33 = list(xm3)
ym3 = m3.values()
ym33 = list(ym3)

# %%
tmp = df.loc[(df["Število posameznikov - SKUPAJ"]!=0)]
z1 = {}
for i,j in zip(tmp["NAMEN UPORABE INTERNETA"], tmp["Ženske 16-24"]):
    if i not in z1.keys():
        z1[i] = j;
    else:
        z1[i] += j;
        
z1 = {k: v for k, v in sorted(z1.items(), key=lambda item: item[1], reverse=True)}
xz1 = z1.keys()
xz11 = list(xz1)
yz1 = z1.values()
yz11 = list(yz1)

# %%
tmp = df.loc[(df["Število posameznikov - SKUPAJ"]!=0)]
z2 = {}
for i,j in zip(tmp["NAMEN UPORABE INTERNETA"], tmp["Ženske 25-54"]):
    if i not in z2.keys():
        z2[i] = j;
    else:
        z2[i] += j;
         
z2 = {k: v for k, v in sorted(z2.items(), key=lambda item: item[1], reverse=True)}
xz2 = z2.keys()
xz22 = list(xz2)
yz2 = z2.values()
yz22 = list(yz2)

# %%
tmp = df.loc[(df["Število posameznikov - SKUPAJ"]!=0)]
z3 = {}
for i,j in zip(tmp["NAMEN UPORABE INTERNETA"], tmp["Ženske 55-74"]):
    if i not in z3.keys():
        z3[i] = j
    else:
        z3[i] += j
        
        
z3 = {k: v for k, v in sorted(z3.items(), key=lambda item: item[1], reverse=True)}
xz3 = z3.keys()
xz33 = list(xz3)
yz3 = z3.values()
yz33 = list(yz3)

# %%
print("Moški in ženske startosti 16-24:")
for i,j in zip(xm11[2:7],xz11[2:7]):
    print(i.replace(".","") , " -> ", j.replace(".",""))
# Out:
# Moški in ženske startosti 16-24:
# Pošiljanje ali prejemanje e-pošte  ->  Pošiljanje ali prejemanje e-pošte
# Sodelovanje v spletnih družabnih omrežjih  ->  Sodelovanje v spletnih družabnih omrežjih
# Iskanje informacij o blagu, storitvah  ->  Iskanje informacij o blagu, storitvah
# Branje spletni novic, spletnih èasopisov, spletnih revij  ->  Iskanje informacij, povezanih z zdravjem
# Telefoniranje ali video telefoniranje s spletno kamero prek interneta  ->  Branje spletni novic, spletnih èasopisov, spletnih revij

# %%
print("Moški in ženske startosti 25-54:")
for i,j in zip(xm22[2:7],xz22[2:7]):
    print(i.replace(".","") , " -> ", j.replace(".",""))
# Out:
# Moški in ženske startosti 25-54:
# Pošiljanje ali prejemanje e-pošte  ->  Pošiljanje ali prejemanje e-pošte
# Iskanje informacij o blagu, storitvah  ->  Iskanje informacij o blagu, storitvah
# Branje spletni novic, spletnih èasopisov, spletnih revij  ->  Iskanje informacij, povezanih z zdravjem
# Sodelovanje v spletnih družabnih omrežjih  ->  Branje spletni novic, spletnih èasopisov, spletnih revij
# E-banèništvo  ->  Sodelovanje v spletnih družabnih omrežjih

# %%
print("Moški in ženske startosti 55-74:")
for i,j in zip(xm33[2:7],xz33[2:7]):
    print(i.replace(".","") , " -> ", j.replace(".",""))
# Out:
# Moški in ženske startosti 55-74:
# Iskanje informacij o blagu, storitvah  ->  Iskanje informacij o blagu, storitvah
# Pošiljanje ali prejemanje e-pošte  ->  Pošiljanje ali prejemanje e-pošte
# Branje spletni novic, spletnih èasopisov, spletnih revij  ->  Iskanje informacij, povezanih z zdravjem
# Iskanje informacij, povezanih z zdravjem  ->  Branje spletni novic, spletnih èasopisov, spletnih revij
# E-banèništvo  ->  E-banèništvo
