# %% [markdown]
# **Uvod**

# %% [markdown]
# Za seminarsko nalogo sva se odločila, da bova analizirala podatke o uporabi interneta in sicer od leta 2015 do 2020 razdeljeno po spolu in starosti. Podatki so izgledali tako:

# %% [markdown]
# ![Slika1.png](attachment:Slika1.png)

# %% [markdown]
# Imela sva 58 namenov uporabe interneta. Od pošiljanja e pište, do iskanje informacij o zdravju itd...
# Iz podatkov sva odstranila dejavnosti katerih anketiranci ne uporabljajo.

# %% [markdown]
# Vsako leto je bilo anketiranih približno 1.000.000 ljudi. Število anketirancev je s časoma rastlo in prav tako tudi število rednih uporabnikov interneta.

# %% [markdown]
# ![Slika2.png](attachment:Slika2.png)

# %% [markdown]
# Število rednih uporabnikov v splošnem raste, ko gledamo po starosti pa dobimo zanimive podatke.

# %% [markdown]
# ![Slika3.png](attachment:Slika3.png)

# %% [markdown]
# 16-24:
# Saj so najmlajši in odraščali skupaj z razvojem interneta, se redni uporabniki interneta (v zadnjih 3 mesecih) gibljejo isto kot vsi uporabiki.

# %% [markdown]
# 24-35:
# Zanimivo je to, da je edina starostna skupina, ki ne raste.

# %% [markdown]
# 45-75:
# Od tukaj naprej grafi začnejo rasti. Začne se starost, kjer niso vsi odraščali z internetom.

# %% [markdown]
# **Najbolj uporabljena dejavnost po letih**

# %% [markdown]
# ![Slika4.png](attachment:Slika4.png)

# %% [markdown]
# Z izjemo leta 2017 je bil najbolj popularen namen pošiljanje ali prejemanje e-pošte.

# %% [markdown]
# **Najbolj uporabljena dejavnost po Starosti**

# %% [markdown]
# ![Slika5.png](attachment:Slika5.png)

# %% [markdown]
# Razvidno je da glede na starost, se tudi namen uporabe spreminja. Pri mlajših generacijah je poleg constant, ki sta e-pošta in iskanje informacijo blagu in storitvah, najbolj uporabljen namen sodelovanje v spletnih družabnih omrežji ter telefoniranje ali video telefoniranje s spletno kamero preko interneta. Pri srednjih letih vstopi e-bančništvo. Pri starejših generacijah glavni namen prevzame iskanje informacij o blagu in storitvah.

# %% [markdown]
# **Katere dejavnosti so skozi leta bile najbolj uporabljene?**

# %% [markdown]
# Podatke sem preuredil, da sem za vsako dejavnost dobil število uporabnikov, ki so jo uporabljali v petih letih. Nato sem jih še sortiral po velikosti od največjega do najmanjšega in tako dobil najbolj uporabljene namene uporabe interneta. V petih letih so nabrali podatke za 9.274.158 ljudi (približno 1,5 milijona letno). Za prikaz najbolj uporabljenih namenov uporabe sem izrisal barh graf.

# %% [markdown]
# ![Slika6.png](attachment:Slika6.png)

# %% [markdown]
# Iz grafa se razberem, da sta zdaleč najbolj uporabljena namena pošiljanje ali prejemanje e-pošte in pa iskanje informacij o blagu, storitvah. Naslednji nameni namreč zaostajajo za dober milijon obiskov.

# %% [markdown]
# **Kako se popularnost določenega namena uporabe interneta spreminja skozi leta?**

# %% [markdown]
# Ko sem dobil podatke za najbolj uporabljene namene uporabe interneta, me je nato zanimalo tudi kako se giblje njihova poraba skozi leta. So nekateri nameni samo »muhe enodnevnice« ali so vsi tako popularni, da njihova popularnost skozi leta ne pada? Odločil sem se, da bom to najlažje prikazal z grafom, ki za vsako leto prikaže procentualno uporabo namena glede na celotno populacijo tega leta.

# %% [markdown]
# ![Slika61.png](attachment:Slika61.png)

# %% [markdown]
# Iz grafov lahko razberem, da popularnost e-maila raste konstantno, med tem ko je popularnost informacije o blagu in storitvah je leta 2018 malenkost padla, ampak si naslednje leto spet opomogla. Vidim pa lahko tudi, da popularnost informacije o zdravju zelo niha, saj nanj vplivajo takratne okoliščine (npr. leta 2020 vidimo velik skok v popularnosti, predvidevam da zaradi covid-19)

# %% [markdown]
# **Razlike med najbolj popularnimi nameni uporabe interneta skozi leta 2015-2020**

# %% [markdown]
# Zdaj ko sem imel idejo kateri so bili najbolj popularni nameni uporabe interneta čez vseh pet let, me je še zanimalo kako se razlikujejo najbolj popularni skozi vsako leto posebej. Zato sem naredil šest podtabel in jih napolnil z podatki za vsako leto. Spet sem izpisal prvih pet najbolj popularnih namenov in jih primerjal.

# %% [markdown]
# ![Slika7.png](attachment:Slika7.png)

# %% [markdown]
# Iz izpisov sem ugotovil, da kljub temu da je pošiljanje ali prejemanje e-pošte prevladovalo prve dve leti, ga v naslednjih štirih letih za prvo mesto vsakič prehiti iskanje informacij, povezanih z zdravjem (oba pa sta vedno na prvem ali drugem mestu). Tretje in četrto mesto je vseh šest let zasedeno z branjem spletnih novic, spletnih časopisov, spletnih revij in pa z iskanjem informacij, povezanih z zdravjem. Peto mesto pa ima največ sprememb, v šestih letih nanj pridejo: uporaba storitev, povezanih s potovanji in nastanitvijo; gledanje video vsebin na spletnih straneh za deljenje video vsebin; sodelovanje v spletnih družabnih ali profesionalnih omrežjih.

# %% [markdown]
# **Pri katerem starostnem razredu je največja oz. najmanjša razlika med spoloma**

# %% [markdown]
# Za konec me je še zanimalo pri katerem starostnem razredu je najmanjša oz. največja razlika med petimi najbolj popularnimi nameni za uporabo interneta. Spet sem naredil šest podtabel in v njih vpisal podatke za vsako starostno skupino glede na spol.

# %% [markdown]
# ![Slika10.png](attachment:Slika10.png)

# %% [markdown]
# Pri starostih 16-24 lahko vidimo, da so prva tri mesta pri obeh ista, med tem ko se zadnji dve mesti razlikujeta. Opazimo pa tudi, da kljub temu, da je na različnih mestih pri obeh na top pet mesti spada branje spletnih novic, časopisov, revij.

# %% [markdown]
# ![Slika11.png](attachment:Slika11.png)

# %% [markdown]
# Za starosti 25-54 se prva razlika pojavi že na drugem mestu. A kljub temu so med prvimi petimi še vedno skoraj isti nameni. Dejanskih čisto različnih namenov je torej isto število kot pri mlajši starostni skupini.

# %% [markdown]
# ![Slika12.png](attachment:Slika12.png)

# %% [markdown]
# Pri zadnji starosti skupini pa kljub temu da so mesta malenkost premešana ne vidimo velikih odstopanj med nameni uporabe interneta.

# %% [markdown]
# Torej na hitro lahko sklepamo, da ima najmanjša odstopanja med spoli najstarejša starostna skupina (55-74), med tem ko ima starostna skupina 25-54 med spoli največja odstopanja.
